# %% [markdown]
# # Customer Segmentation using K-Means Clustering

# %%
# !pip install pandas matplotlib seaborn scikit-learn
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans

# %%
df = pd.read_csv('Mall_Customers.csv')
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
# Check missing values
df.isnull().sum()

# Drop unnecessary column
df = df.drop('CustomerID', axis=1)

# Convert Gender
df['Gender'] = df['Gender'].map({'Male':1, 'Female':0})

# %%
df.describe()
# Out:
#            Gender         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean     0.440000   38.850000           60.560000               50.200000
# std      0.497633   13.969007           26.264721               25.823522
# min      0.000000   18.000000           15.000000                1.000000
# 25%      0.000000   28.750000           41.500000               34.750000
# 50%      0.000000   36.000000           61.500000               50.000000
# 75%      1.000000   49.000000           78.000000               73.000000
# max      1.000000   70.000000          137.000000               99.000000

# %%
plt.scatter(df['Annual Income (k$)'], df['Spending Score (1-100)'])
plt.xlabel("Income")
plt.ylabel("Spending Score")
plt.show()

# %%
X = df[['Annual Income (k$)', 'Spending Score (1-100)']]

wcss = []
for i in range(1,11):
    kmeans = KMeans(n_clusters=i, random_state=42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

plt.plot(range(1,11), wcss)
plt.title("Elbow Method")
plt.show()

# %%
kmeans = KMeans(n_clusters=5, random_state=42)
df['Cluster'] = kmeans.fit_predict(X)

# %%
for i in range(5):
    plt.scatter(
        df[df['Cluster']==i]['Annual Income (k$)'],
        df[df['Cluster']==i]['Spending Score (1-100)']
    )

plt.show()

# %% [markdown]
# # Customer Segmentation using K-Means
#
# ## Problem
# This project aims to identify customer segments based on income and spending behavior.
#
# ## Dataset
# Mall Customers dataset including age, gender, income, and spending score.
#
# ## Method
# - Data Cleaning
# - Exploratory Data Analysis
# - K-Means Clustering
# - Elbow Method
#
# ## Results
# Identified 5 customer segments including high-value target customers.
#
# ## Tools
# Python, Pandas, Matplotlib, Scikit-learn

# %% [markdown]
# ## Interpretation of Results
#
# The clustering results show five distinct customer groups.
# Customers with high income and high spending are identified as target customers.
# Customers with high income but low spending represent an opportunity for marketing improvement.
